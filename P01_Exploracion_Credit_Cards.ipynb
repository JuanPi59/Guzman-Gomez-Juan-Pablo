# %% [markdown]
# # Tarjetas de Credito
# ### La base de datos muestra los balances, limites de credito, pagos minimos, cargos y montos, entre otros datos relevantes sobre cuentas de tarjetas de credito.

# %%
import numpy as np
import pandas as pd
import missingno as msno
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
path = 'CC GENERAL.csv'
df = pd.read_csv(path)
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
# CUST_ID                             8950 non-null object
# BALANCE                             8950 non-null float64
# BALANCE_FREQUENCY                   8950 non-null float64
# PURCHASES                           8950 non-null float64
# ONEOFF_PURCHASES                    8950 non-null float64
# INSTALLMENTS_PURCHASES              8950 non-null float64
# CASH_ADVANCE                        8950 non-null float64
# PURCHASES_FREQUENCY                 8950 non-null float64
# ONEOFF_PURCHASES_FREQUENCY          8950 non-null float64
# PURCHASES_INSTALLMENTS_FREQUENCY    8950 non-null float64
# CASH_ADVANCE_FREQUENCY              8950 non-null float64
# CASH_ADVANCE_TRX                    8950 non-null int64
# PURCHASES_TRX                       8950 non-null int64
# CREDIT_LIMIT                        8949 non-null float64
# ...

# %%
df.shape
# Out:
# (8950, 18)

# %%
df.isnull().any().any()
# Out:
# True

# %%
msno.matrix(df)

# %%
df.replace({' ': np.nan}, inplace=True)

# %%
df.isnull().any().any()
# Out:
# True

# %%
df.isnull().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
msno.matrix(df)

# %%
msno.bar(df)

# %%
df.columns[df.isnull().any()].tolist()
# Out:
# ['CREDIT_LIMIT', 'MINIMUM_PAYMENTS']

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# ...

# %%
df.agg(['count', 'size', 'nunique'])
# Out:
#          CUST_ID  BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# count       8950     8950               8950       8950              8950
# size        8950     8950               8950       8950              8950
# nunique     8950     8871                 43       6203              4014
#
#          INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count                      8950          8950                 8950
# size                       8950          8950                 8950
# nunique                    4452          4323                   47
#
#          ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                          8950                              8950
# size                           8950                              8950
# nunique                          47                                47
#
#          CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# ...

# %%
df.plot(kind='scatter',x='BALANCE',y='MINIMUM_PAYMENTS')

# %%
df.plot(kind='scatter',x='BALANCE',y='CREDIT_LIMIT')

# %%
df.plot(kind='scatter',x='MINIMUM_PAYMENTS',y='PAYMENTS')

# %%
df.plot(kind='scatter',x='CREDIT_LIMIT',y='MINIMUM_PAYMENTS')

# %%
df=df.dropna()

# %%
plt.hist(df['BALANCE'])
plt.xlabel('Balances')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Balances')
# Out:
# Text(0.5, 1.0, 'Frecuencia de Balances')

# %%
plt.hist(df['CREDIT_LIMIT'])
plt.xlabel('Limites de credito')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de limites de credito')
# Out:
# Text(0.5, 1.0, 'Frecuencia de limites de credito')

# %%
plt.hist(df['MINIMUM_PAYMENTS'])
plt.xlabel('Pagos Minimos')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Pagos Minimos')
# Out:
# Text(0.5, 1.0, 'Frecuencia de Pagos Minimos')

# %%
plt.hist(df['PURCHASES'])
plt.xlabel('Compras')
plt.ylabel('Frecuencia')
plt.title('Frecuencia de Compras')
# Out:
# Text(0.5, 1.0, 'Frecuencia de Compras')

# %%
plt.boxplot(df['CREDIT_LIMIT'],showmeans=True, meanline=True)
plt.ylabel('Limites de credito')
plt.title('Box Plot de Limites de credito')
# Out:
# Text(0.5, 1.0, 'Box Plot de Limites de credito')

# %%
plt.boxplot(df['BALANCE'], showmeans=True, meanline=True)
plt.ylabel('Balances')
plt.title('Box Plot de Balances')
# Out:
# Text(0.5, 1.0, 'Box Plot de Balances')

# %%
plt.boxplot(df['MINIMUM_PAYMENTS'], showmeans=True, meanline=True)
plt.ylabel('Pagos minimos')
plt.title('Box Plot de pagos minimos')
# Out:
# Text(0.5, 1.0, 'Box Plot de pagos minimos')

# %%
plt.boxplot(df['PURCHASES'], showmeans=True, meanline=True)
plt.ylabel('Compras')
plt.title('Box Plot de Compras')
# Out:
# Text(0.5, 1.0, 'Box Plot de Compras')
